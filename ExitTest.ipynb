# %%
#Importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Getting the file data
data=pd.read_csv('/home/neethu/Downloads/train (2).csv')

# %% [markdown]
# # Displaying dataset

# %%
data.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
# Display basic information about the dataset
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13994 entries, 0 to 13993
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player_id                  13994 non-null  object
#  1   name                       13994 non-null  object
#  2   age                        13994 non-null  int64
#  3   gender                     13975 non-null  object
#  4   country                    13994 non-null  object
#  5   height                     13994 non-null  object
#  6   weight                     13577 non-null  object
#  7   ball_controlling_skills    13581 non-null  float64
#  8   body_reflexes              13994 non-null  float64
#  9   body_balance               13994 non-null  float64
#  10  jumping_skills             13970 non-null  float64
#  11  penalties_conversion_rate  13964 non-null  float64
#  12  mental_strength            13966 non-null  float64
# ...

# %%
# Summary statistics
data.describe()
# Out:
#                 age  ball_controlling_skills  body_reflexes  body_balance  \
# count  13994.000000             13581.000000   13994.000000  13994.000000
# mean      21.135844                56.043958      61.934329     62.753323
# std        5.162719                16.787353      14.931963     14.203638
# min       16.000000                 5.000000      12.000000      9.000000
# 25%       17.000000                51.000000      54.000000     55.000000
# 50%       20.000000                61.000000      64.000000     65.000000
# 75%       24.000000                67.000000      72.000000     73.000000
# max       61.000000                95.000000      96.000000     97.000000
#
#        jumping_skills  penalties_conversion_rate  mental_strength  \
# count    13970.000000               13964.000000     13966.000000
# mean        63.612026                  48.495703        56.768366
# std         11.938712                  15.767506        11.977744
# ...

# %%
#Checking the dataset column
data.columns
# Out:
# Index(['player_id', 'name', 'age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %%
#Lets check the shape of dataset
data.shape
# Out:
# (13994, 30)

# %%
# Summary statistics
data.describe()
# Out:
#                 age  ball_controlling_skills  body_reflexes  body_balance  \
# count  13994.000000             13581.000000   13994.000000  13994.000000
# mean      21.135844                56.043958      61.934329     62.753323
# std        5.162719                16.787353      14.931963     14.203638
# min       16.000000                 5.000000      12.000000      9.000000
# 25%       17.000000                51.000000      54.000000     55.000000
# 50%       20.000000                61.000000      64.000000     65.000000
# 75%       24.000000                67.000000      72.000000     73.000000
# max       61.000000                95.000000      96.000000     97.000000
#
#        jumping_skills  penalties_conversion_rate  mental_strength  \
# count    13970.000000               13964.000000     13966.000000
# mean        63.612026                  48.495703        56.768366
# std         11.938712                  15.767506        11.977744
# ...

# %% [markdown]
# We can see from the summary that total count is 13994, however look into ball_controlling_skills, jumping_skills,penalties_conversion_rate,mental_strength ,shot_accuracy and years_of_experience​ etc, we can see that the numbers are less tha 13994, so we can identify that the values are missing.

# %% [markdown]
# # finding coloums with missing values

# %%
features_with_na = [feature for feature in data.columns if data[feature].isna().sum() > 1]

# %%
features_with_na
# Out:
# ['gender',
#  'weight',
#  'ball_controlling_skills',
#  'jumping_skills',
#  'penalties_conversion_rate',
#  'mental_strength',
#  'shot_accuracy',
#  'strong_foot',
#  'behaviour_rating',
#  'matches_played',
#  'fitness_rating',
#  'coaching',
#  'years_of_experience']

# %%
# Calculate missing value counts for all columns
missing_value_counts = data.isna().sum()

# %%
#Features with missing values:
# Print missing value counts for each column
for column, count in missing_value_counts.items():
    print(f"Column '{column}': {count} missing values")
# Out:
# Column 'player_id': 0 missing values
# Column 'name': 0 missing values
# Column 'age': 0 missing values
# Column 'gender': 19 missing values
# Column 'country': 0 missing values
# Column 'height': 0 missing values
# Column 'weight': 417 missing values
# Column 'ball_controlling_skills': 413 missing values
# Column 'body_reflexes': 0 missing values
# Column 'body_balance': 0 missing values
# Column 'jumping_skills': 24 missing values
# Column 'penalties_conversion_rate': 30 missing values
# Column 'mental_strength': 28 missing values
# Column 'goalkeeping_skills': 0 missing values
# Column 'defending_skills': 0 missing values
# Column 'passing_skills': 0 missing values
# Column 'dribbling_skills': 0 missing values
# Column 'shot_accuracy': 572 missing values
# Column 'body_strength_stamina': 0 missing values
# Column 'max_running_speed': 0 missing values
# Column 'strong_foot': 552 missing values
# Column 'behaviour_rating': 703 missing values
# ...

# %%
#finding missing values of gender column
data['gender'].isna().sum()
# Out:
# 19

# %%
#finding missing values of weight column
data['weight'].isna().sum()
# Out:
# 417

# %%
#finding missing values of ball_controlling_skills column
data['ball_controlling_skills'].isna().sum()
# Out:
# 413

# %%
#finding missing values of jumping_skills column
data['jumping_skills'].isna().sum()
# Out:
# 24

# %%
#finding missing values of penalties_conversion_rate column
data['penalties_conversion_rate'].isna().sum()
# Out:
# 30

# %%
#finding missing values of mental_strength column
data['mental_strength'].isna().sum()
# Out:
# 28

# %%
#finding missing values of shot_accuracy column
data['shot_accuracy'].isna().sum()
# Out:
# 572

# %%
#finding missing values of strong_foot column
data['strong_foot'].isna().sum()
# Out:
# 552

# %%
#finding missing values of behaviour_rating column
data['behaviour_rating'].isna().sum()
# Out:
# 703

# %%
#finding missing values of matches_played column
data['matches_played'].isna().sum()
# Out:
# 666

# %%
#finding missing values of fitness_rating column
data['fitness_rating'].isna().sum()
# Out:
# 695

# %%
#finding missing values of coaching column
data['coaching'].isna().sum()
# Out:
# 125

# %%
#finding missing values of years_of_experience column
data['years_of_experience'].isna().sum()
# Out:
# 144

# %%
# Calculate missing value counts for all columns
missing_value_counts = data.isna().sum()

# %%
# Print missing value counts for each column
for column, count in missing_value_counts.items():
    print(f" '{column}': {count} missing values")
# Out:
#  'player_id': 0 missing values
#  'name': 0 missing values
#  'age': 0 missing values
#  'gender': 19 missing values
#  'country': 0 missing values
#  'height': 0 missing values
#  'weight': 417 missing values
#  'ball_controlling_skills': 413 missing values
#  'body_reflexes': 0 missing values
#  'body_balance': 0 missing values
#  'jumping_skills': 24 missing values
#  'penalties_conversion_rate': 30 missing values
#  'mental_strength': 28 missing values
#  'goalkeeping_skills': 0 missing values
#  'defending_skills': 0 missing values
#  'passing_skills': 0 missing values
#  'dribbling_skills': 0 missing values
#  'shot_accuracy': 572 missing values
#  'body_strength_stamina': 0 missing values
#  'max_running_speed': 0 missing values
#  'strong_foot': 552 missing values
#  'behaviour_rating': 703 missing values
#  'matches_played': 666 missing values
#  'fitness_rating': 695 missing values
#  'trophies_won': 0 missing values
#  'dedication_level': 0 missing values
# ...

# %% [markdown]
# # Visualization

# %% [markdown]
# # Univariate analysis

# %%
# Univariate analysis for age
plt.figure(figsize=(8, 6))
sns.histplot(data['age'], bins=20, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Convert 'weight' column to numeric (remove non-numeric characters like 'lbs')
data['weight'] = pd.to_numeric(data['weight'].str.replace('lbs', ''), errors='coerce')

# Univariate analysis for weight (after converting to numeric)
plt.figure(figsize=(8, 6))
sns.boxplot(y=data['weight'])
plt.title('Box Plot of Weight')
plt.ylabel('Weight')
plt.show()

# %%
# Univariate analysis for weight (after converting to numeric)
plt.figure(figsize=(8, 6))
sns.boxplot(y=data['weight'])
plt.title('Box Plot of Weight')
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# # Two-Variable Analysis (Bivariate Analysis):

# %% [markdown]
# relationships between pairs of variables to understand correlations, patterns, and potential insights.

# %%
# Bivariate analysis: Age vs. Weight
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='weight', data=data)
plt.title('Age vs. Weight')
plt.xlabel('Age')
plt.ylabel('Weight')
plt.show()

# %%
# Bivariate analysis: Gender vs. Fitness Rating
plt.figure(figsize=(8, 6))
sns.boxplot(x='gender', y='fitness_rating', data=data)
plt.title('Gender vs. Fitness Rating')
plt.xlabel('Gender')
plt.ylabel('Fitness Rating')
plt.show()

# %%
# Bivariate analysis: Age vs. Trophies Won
plt.figure(figsize=(10, 6))
sns.barplot(x='age', y='trophies_won', data=data)
plt.title('Age vs. Trophies Won')
plt.xlabel('Age')
plt.ylabel('Trophies Won')
plt.show()

# %%
# Violin plot: Gender vs. Ball Controlling Skills
plt.figure(figsize=(10, 6))
sns.violinplot(x='gender', y='ball_controlling_skills', data=data)
plt.title('Gender vs. Ball Controlling Skills')
plt.xlabel('Gender')
plt.ylabel('Ball Controlling Skills')
plt.show()

# %%
# Distribution comparison: Fitness Rating by Gender
plt.figure(figsize=(10, 6))
sns.histplot(data, x='fitness_rating', hue='gender', multiple='stack', bins=20, kde=True)
plt.title('Fitness Rating Distribution by Gender')
plt.xlabel('Fitness Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Pair grid: Scatter plots and histograms for numerical variables
numerical_vars = ['age', 'weight', 'body_balance', 'jumping_skills']
pair_grid = sns.PairGrid(data[numerical_vars])
pair_grid.map_upper(sns.scatterplot)
pair_grid.map_lower(sns.kdeplot)
pair_grid.map_diag(sns.histplot)
plt.suptitle('Pair Grid of Numerical Variables')
plt.show()

# %%
# Categorical plot: Dedication Level by Gender
plt.figure(figsize=(10, 6))
sns.countplot(x='dedication_level', hue='gender', data=data)
plt.title('Dedication Level by Gender')
plt.xlabel('Dedication Level')
plt.ylabel('Count')
plt.show()

# %%
# Create a pivot table for Dedication Level and Gender
dedication_gender_pivot = data.pivot_table(index='dedication_level', columns='gender', values='player_id', aggfunc='count')

# %%
# Plot the pivot table using a bar plot
plt.figure(figsize=(10, 6))
dedication_gender_pivot.plot(kind='bar', stacked=True)
plt.title('Dedication Level by Gender')
plt.xlabel('Dedication Level')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# %%
data.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2   176.0
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10   148.0
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2   172.0
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11   165.0
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8   158.0
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %% [markdown]
# # Preprocessing

# %%
# Calculate missing value counts for all columns
missing_value_counts = data.isna().sum()

# %%
#Features with missing values:
# Print missing value counts for each column
for column, count in missing_value_counts.items():
    print(f"Column '{column}': {count} missing values")
# Out:
# Column 'player_id': 0 missing values
# Column 'name': 0 missing values
# Column 'age': 0 missing values
# Column 'gender': 19 missing values
# Column 'country': 0 missing values
# Column 'height': 0 missing values
# Column 'weight': 417 missing values
# Column 'ball_controlling_skills': 413 missing values
# Column 'body_reflexes': 0 missing values
# Column 'body_balance': 0 missing values
# Column 'jumping_skills': 24 missing values
# Column 'penalties_conversion_rate': 30 missing values
# Column 'mental_strength': 28 missing values
# Column 'goalkeeping_skills': 0 missing values
# Column 'defending_skills': 0 missing values
# Column 'passing_skills': 0 missing values
# Column 'dribbling_skills': 0 missing values
# Column 'shot_accuracy': 572 missing values
# Column 'body_strength_stamina': 0 missing values
# Column 'max_running_speed': 0 missing values
# Column 'strong_foot': 552 missing values
# Column 'behaviour_rating': 703 missing values
# ...

# %% [markdown]
# # Handling missing values

# %% [markdown]
# #Since 'gender' is a categorical variable, you could impute the missing values with the mode (most frequent category).

# %%
data['gender'].fillna(data['gender'].mode()[0], inplace=True)

# %% [markdown]
# 'weight','ball_controlling_skills' columns seem to be numerical. You can consider imputing the missing values with the mean or median of the respective columns.

# %%
data['weight'].fillna(data['weight'].median(), inplace=True)
data['ball_controlling_skills'].fillna(data['ball_controlling_skills'].mean(), inplace=True)

# %% [markdown]
# 'jumping_skills' Column (24 missing values), 'penalties_conversion_rate' Column (30 missing values), and 'mental_strength' Column (28 missing values):
# Similar to the above columns, you can impute the missing values with the mean or median.

# %%
data['jumping_skills'].fillna(data['jumping_skills'].mean(), inplace=True)
data['penalties_conversion_rate'].fillna(data['penalties_conversion_rate'].median(), inplace=True)
data['mental_strength'].fillna(data['mental_strength'].median(), inplace=True)

# %% [markdown]
# 'shot_accuracy' Column (572 missing values):
# If a significant portion of the data is missing in this column, you might consider dropping it, especially if it's not a critical feature for your analysis.

# %%
data.drop('shot_accuracy', axis=1, inplace=True)

# %% [markdown]
# 'strong_foot' Column (552 missing values):
# Since 'strong_foot' is a categorical variable, you can impute the missing values with the mode.

# %%
data['strong_foot'].fillna(data['strong_foot'].mode()[0], inplace=True)

# %% [markdown]
# 'behaviour_rating', 'matches_played', 'fitness_rating' Columns:
# These columns might be numerical or categorical. If they are numerical, consider imputing with the mean or median.

# %%
data['behaviour_rating'].fillna(data['behaviour_rating'].mean(), inplace=True)
data['matches_played'].fillna(data['matches_played'].median(), inplace=True)
data['fitness_rating'].fillna(data['fitness_rating'].median(), inplace=True)

# %% [markdown]
# 'coaching' and 'years_of_experience' Columns (125 and 144 missing values, respectively):
# Depending on the nature of these columns, you can consider imputing with mean, median, or mode.

# %%
data['coaching'].fillna(data['coaching'].mode()[0], inplace=True)
data['years_of_experience'].fillna(data['years_of_experience'].median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# player_id                    0
# name                         0
# age                          0
# gender                       0
# country                      0
# height                       0
# weight                       0
# ball_controlling_skills      0
# body_reflexes                0
# body_balance                 0
# jumping_skills               0
# penalties_conversion_rate    0
# mental_strength              0
# goalkeeping_skills           0
# defending_skills             0
# passing_skills               0
# dribbling_skills             0
# body_strength_stamina        0
# max_running_speed            0
# strong_foot                  0
# behaviour_rating             0
# matches_played               0
# fitness_rating               0
# trophies_won                 0
# dedication_level             0
# coaching                     0
# years_of_experience          0
# no_of_disqualifications      0
# selection                    0
# dtype: int64

# %% [markdown]
# ALL NULL VALUES ARE HANDLED

# %% [markdown]
# # outliers Detection

# %%
# Select numerical columns with potential outliers
numerical_columns = ['age'
                     ,'ball_controlling_skills', 'body_reflexes', 'body_balance',
                     'jumping_skills', 'penalties_conversion_rate', 'mental_strength', 'goalkeeping_skills',
                     'defending_skills', 'passing_skills', 'dribbling_skills', 'body_strength_stamina',
                     'max_running_speed', 'behaviour_rating', 'matches_played', 'fitness_rating',
                      'no_of_disqualifications']

# %%
plt.figure(figsize=(20, 15))
for column in numerical_columns:
    plt.subplot(4, 6, numerical_columns.index(column) + 1)
    sns.boxplot(data[column])
    plt.title(column)
    plt.tight_layout()

plt.show()

# %%
from scipy.stats import zscore

# Calculate z-scores for numerical columns
z_scores = data[numerical_columns].apply(zscore)

# Identify data points with z-scores above a threshold (e.g., 3)
threshold = 3
outliers = (z_scores > threshold) | (z_scores < -threshold)

# Print rows containing outliers
outliers_rows = data[outliers.any(axis=1)]
print(outliers_rows)
# Out:
#         player_id                 name  age gender       country height  \
# 3      PLID_17467       Andrea Badgett   27      M         Chile   5'11
# 32      PLID_4108  Joaquin Santistevan   27      M         Italy    6'4
# 57     PLID_22254         Pamula Edick   21      M       Belgium   5'10
# 58     PLID_10617       Rosia Orndorff   17      F      Slovakia    6'5
# 75     PLID_11994          Rex Bruneau   51      F      Slovenia   5'11
# ...           ...                  ...  ...    ...           ...    ...
# 13933  PLID_10120         Cyrus Wolter   18      M       Croatia    6'9
# 13945  PLID_11033       Narcisa Freese   19      F       Albania    6'4
# 13954   PLID_4075          Len Saylors   51      M  Saudi Arabia   5'10
# 13964   PLID_6286         Phung Buzbee   25      F       Belgium    6'4
# 13969  PLID_19434        Fatima Perone   24      F         Spain    6'2
#
#        weight  ball_controlling_skills  body_reflexes  body_balance  ...  \
# ...

# %% [markdown]
# # Handling outliers

# %%
# Calculate IQR for numerical columns
Q1 = data[numerical_columns].quantile(0.25)
Q3 = data[numerical_columns].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for identifying outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Cap outliers in each numerical column
for col in numerical_columns:
    data[col] = np.where(data[col] < lower_bound[col], lower_bound[col], data[col])
    data[col] = np.where(data[col] > upper_bound[col], upper_bound[col], data[col])

# %%
plt.figure(figsize=(20, 15))
for column in numerical_columns:
    plt.subplot(4, 6, numerical_columns.index(column) + 1)
    sns.boxplot(data[column])
    plt.title(column)
    plt.tight_layout()

plt.show()

# %%
data.head()
# Out:
#     player_id                 name   age gender    country height  weight  \
# 0   PLID_4964           Keva Horan  23.0      M    Ukraine    6'2   176.0
# 1  PLID_11234           Herma Tann  18.0      M     Russia   5'10   148.0
# 2  PLID_19127         Eilene Kizer  16.0      F      Spain    6'2   172.0
# 3  PLID_17467       Andrea Badgett  27.0      M      Chile   5'11   165.0
# 4   PLID_9661  Jeremiah Bumbalough  19.0      F  Argentina    5'8   158.0
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
# Data preprocessing: Convert height from feet' inches" format to centimeters
def feet_inches_to_cm(height):
    feet, inches = map(int, height.split("'"))
    total_inches = feet * 12 + inches
    cm = total_inches * 2.54
    return cm

# %%
data['height_cm'] = data['height'].apply(feet_inches_to_cm)

# %%
# Drop the original 'height' column
data.drop('height', axis=1, inplace=True)

# %%
data.head()
# Out:
#     player_id                 name   age gender    country  weight  \
# 0   PLID_4964           Keva Horan  23.0      M    Ukraine   176.0
# 1  PLID_11234           Herma Tann  18.0      M     Russia   148.0
# 2  PLID_19127         Eilene Kizer  16.0      F      Spain   172.0
# 3  PLID_17467       Andrea Badgett  27.0      M      Chile   165.0
# 4   PLID_9661  Jeremiah Bumbalough  19.0      F  Argentina   158.0
#
#    ball_controlling_skills  body_reflexes  body_balance  jumping_skills  ...  \
# 0                     77.0           58.0          47.0            59.0  ...
# 1                     54.0           69.0          70.0            62.0  ...
# 2                     34.0           43.0          45.0            69.0  ...
# 3                     79.0           73.0          76.0            86.0  ...
# 4                     47.0           61.0          74.0            57.0  ...
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %% [markdown]
# # Feature Engineering:

# %%
#creating age group from age
def categorize_age(age):
    if age < 18:
        return 'Teen'
    elif 18 <= age < 30:
        return 'Young Adult'
    elif 30 <= age < 50:
        return 'Adult'
    else:
        return 'Senior'

data['age_group'] = data['age'].apply(categorize_age)

# %%
# Drop the original 'age' column
data.drop('age', axis=1, inplace=True)

# %%
#BMI (Body Mass Index): calucuation from weight and height
data['bmi'] = data['weight'] / ((data['height_cm'] / 100) ** 2)

# %%
# Drop the original 'height_cm' column
data.drop('height_cm', axis=1, inplace=True)

# %%
# Drop the original 'weight' column
data.drop('weight', axis=1, inplace=True)

# %%
data.head()
# Out:
#     player_id                 name gender    country  ball_controlling_skills  \
# 0   PLID_4964           Keva Horan      M    Ukraine                     77.0
# 1  PLID_11234           Herma Tann      M     Russia                     54.0
# 2  PLID_19127         Eilene Kizer      F      Spain                     34.0
# 3  PLID_17467       Andrea Badgett      M      Chile                     79.0
# 4   PLID_9661  Jeremiah Bumbalough      F  Argentina                     47.0
#
#    body_reflexes  body_balance  jumping_skills  penalties_conversion_rate  \
# 0           58.0          47.0            59.0                       41.0
# 1           69.0          70.0            62.0                       53.0
# 2           43.0          45.0            69.0                       49.0
# 3           73.0          76.0            86.0                       81.0
# 4           61.0          74.0            57.0                       49.0
#
# ...

# %% [markdown]
# #

# %%
# data.head()

# %% [markdown]
# # Feature Reduction:

# %% [markdown]
# Correlation Analysis:

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# /tmp/ipykernel_15932/513684470.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
# Drop features with low correlation to 'selection'
low_corr_threshold = 0.1
low_corr_features = correlation_matrix[correlation_matrix['selection'].abs() < low_corr_threshold].index
data.drop(low_corr_features, axis=1, inplace=True)

# %%
data.head()
# Out:
#     player_id                 name gender    country  ball_controlling_skills  \
# 0   PLID_4964           Keva Horan      M    Ukraine                     77.0
# 1  PLID_11234           Herma Tann      M     Russia                     54.0
# 2  PLID_19127         Eilene Kizer      F      Spain                     34.0
# 3  PLID_17467       Andrea Badgett      M      Chile                     79.0
# 4   PLID_9661  Jeremiah Bumbalough      F  Argentina                     47.0
#
#    body_reflexes  body_balance  penalties_conversion_rate  mental_strength  \
# 0           58.0          47.0                       41.0             73.0
# 1           69.0          70.0                       53.0             43.0
# 2           43.0          45.0                       49.0             45.0
# 3           73.0          76.0                       81.0             80.0
# 4           61.0          74.0                       49.0             35.0
#
# ...

# %% [markdown]
# # Handling Categorical Data: Convert categorical variables using one-hot encoding.

# %%
categorical_columns = ['gender', 'strong_foot', 'dedication_level', 'coaching', 'age_group']
data = pd.get_dummies(data, columns=categorical_columns, drop_first=True)

# %%
data.head()
# Out:
#     player_id                 name    country  ball_controlling_skills  \
# 0   PLID_4964           Keva Horan    Ukraine                     77.0
# 1  PLID_11234           Herma Tann     Russia                     54.0
# 2  PLID_19127         Eilene Kizer      Spain                     34.0
# 3  PLID_17467       Andrea Badgett      Chile                     79.0
# 4   PLID_9661  Jeremiah Bumbalough  Argentina                     47.0
#
#    body_reflexes  body_balance  penalties_conversion_rate  mental_strength  \
# 0           58.0          47.0                       41.0             73.0
# 1           69.0          70.0                       53.0             43.0
# 2           43.0          45.0                       49.0             45.0
# 3           73.0          76.0                       81.0             80.0
# 4           61.0          74.0                       49.0             35.0
#
#    defending_skills  passing_skills  ...  strong_foot_Left  strong_foot_None  \
# ...

# %%
#Scaling
import pandas as pd
from sklearn.preprocessing import StandardScaler



# Separate the target variable ('selection') from the features
# X = data.drop('selection', axis=1)
# Select features and target
X = data.drop(columns=['selection', 'player_id', 'name','country'])  # Drop player_id and name
y = data['selection']

# Get the column names of the numeric features
numeric_features = X.select_dtypes(include='number').columns

# Create the StandardScaler object
scaler = StandardScaler()

# Standardize the numeric features
X[numeric_features] = scaler.fit_transform(X[numeric_features])

# Now the numeric features in X are standardized with mean=0 and std=1

# %%
data.head()
# Out:
#     player_id                 name    country  ball_controlling_skills  \
# 0   PLID_4964           Keva Horan    Ukraine                     77.0
# 1  PLID_11234           Herma Tann     Russia                     54.0
# 2  PLID_19127         Eilene Kizer      Spain                     34.0
# 3  PLID_17467       Andrea Badgett      Chile                     79.0
# 4   PLID_9661  Jeremiah Bumbalough  Argentina                     47.0
#
#    body_reflexes  body_balance  penalties_conversion_rate  mental_strength  \
# 0           58.0          47.0                       41.0             73.0
# 1           69.0          70.0                       53.0             43.0
# 2           43.0          45.0                       49.0             45.0
# 3           73.0          76.0                       81.0             80.0
# 4           61.0          74.0                       49.0             35.0
#
#    defending_skills  passing_skills  ...  strong_foot_Left  strong_foot_None  \
# ...

# %% [markdown]
# # # Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# # Modeling

# %%
#import models
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
# Initialize models
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'SVM': SVC()
}

# %%
# Train and evaluate each model
for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f'{model_name} Accuracy: {accuracy:.2f}')
# Out:
# Logistic Regression Accuracy: 0.77
# Decision Tree Accuracy: 0.76
# Random Forest Accuracy: 0.83
# SVM Accuracy: 0.82

# %% [markdown]
# most accurancy is for random forest model so we selcet that model

# %% [markdown]
# #  hyperparameter tuning for a Random Forest
#  # Fine tunning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# Define the parameter grid to search through
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Create a Random Forest classifier
rf_model = RandomForestClassifier(random_state=42)

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, scoring='accuracy', verbose=2)

# Fit the grid search to your training data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters
print("Best hyperparameters:", grid_search.best_params_)

# Get the best model
best_rf_model = grid_search.best_estimator_

# Evaluate the model on the test set
y_pred = best_rf_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy on test set:", accuracy)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.7s
# ...

# %% [markdown]
# # Accuracy on test set: 0.8350957416404687

# %%
# already trained and fine-tuned the model using GridSearchCV

# Make predictions on the test set
y_pred = best_rf_model.predict(X_test)

# %%
# Print the predictions
print(y_pred)
# Out:
# [0 0 1 ... 1 0 1]

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 1, 0, 1])
